# %%
import pandas as pd
df= pd.read_csv('cleandemp_data.csv')
df1 = df.copy()

# %%
df
# Out:
#               department         education gender  no_of_trainings  age  \
# 0      Sales & Marketing  Master's & above      f                1   35
# 1             Operations        Bachelor's      m                1   30
# 2      Sales & Marketing        Bachelor's      m                1   34
# 3      Sales & Marketing        Bachelor's      m                2   39
# 4             Technology        Bachelor's      m                1   45
# ...                  ...               ...    ...              ...  ...
# 45956  Sales & Marketing        Bachelor's      m                2   31
# 45957         Technology        Bachelor's      m                1   48
# 45958         Operations  Master's & above      f                1   37
# 45959          Analytics        Bachelor's      m                1   27
# 45960                 HR        Bachelor's      m                1   27
#
#        previous_year_rating  length_of_service  awards_won  \
# ...

# %%
df.filter(items=['is_promoted'])
# Out:
#        is_promoted
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 45956            0
# 45957            0
# 45958            0
# 45959            0
# 45960            0
#
# [45961 rows x 1 columns]

# %%
df1=df[(df['is_promoted'] > 0)]
df1
# Out:
#               department         education gender  no_of_trainings  age  \
# 10     Sales & Marketing        Bachelor's      f                1   35
# 33     Sales & Marketing        Bachelor's      m                1   33
# 51     Sales & Marketing  Master's & above      m                1   50
# 57             Analytics        Bachelor's      m                1   30
# 59            Technology  Master's & above      m                1   34
# ...                  ...               ...    ...              ...  ...
# 45893  Sales & Marketing        Bachelor's      m                1   29
# 45916         Technology  Master's & above      m                1   54
# 45920        Procurement        Bachelor's      f                1   30
# 45947  Sales & Marketing        Bachelor's      m                1   59
# 45951  Sales & Marketing  Master's & above      m                1   34
#
#        previous_year_rating  length_of_service  awards_won  \
# ...

# %%
X = df1.iloc[:,0:9]
y = df1['is_promoted']

# %%
X.head(1)
# Out:
#           department         education gender  no_of_trainings  age  \
# 0  Sales & Marketing  Master's & above      f                1   35
#
#    previous_year_rating  length_of_service  awards_won  avg_training_score
# 0                   5.0                  8           0                49.0

# %%
y
# Out:
# 10       1
# 33       1
# 51       1
# 57       1
# 59       1
#         ..
# 45893    1
# 45916    1
# 45920    1
# 45947    1
# 45951    1
# Name: is_promoted, Length: 4037, dtype: int64

# %%
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
dm = DataFrameMapper([(['department',LabelEncoder()]),(["education",LabelEncoder()]),
                      (["gender",LabelEncoder()])])

# %%
dm
# Out:
# DataFrameMapper(drop_cols=[],
#                 features=[['department', LabelEncoder()],
#                           ['education', LabelEncoder()],
#                           ['gender', LabelEncoder()]])

# %%
ml = []
ml.append(['mapper',dm])
ml.append(['SC',StandardScaler()])
ml.append(['RF',RandomForestClassifier()])

# %%
from sklearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# %%
model = Pipeline(ml)
model.fit(X,y)
# Out:
# Pipeline(steps=[('mapper',
#                  DataFrameMapper(drop_cols=[],
#                                  features=[['department', LabelEncoder()],
#                                            ['education', LabelEncoder()],
#                                            ['gender', LabelEncoder()]])),
#                 ('SC', StandardScaler()), ['RF', RandomForestClassifier()]])

# %%
dict(df1.iloc[10,:])
# Out:
# {'department': 'Operations',
#  'education': "Bachelor's",
#  'gender': 'm',
#  'no_of_trainings': 1,
#  'age': 35,
#  'previous_year_rating': 4.0,
#  'length_of_service': 6,
#  'awards_won': 0,
#  'avg_training_score': 57.0,
#  'is_promoted': 1}

# %%
new={'department': 'Technology',
 'education': "Master's & above",
 'gender': 'm',
 'no_of_trainings': 1,
 'age': 34,
 'previous_year_rating': 5.0,
 'length_of_service': 7,
 'awards_won': 0,
 'avg_training_score': 78.0
 }

# %%
gf = pd.DataFrame(new,index=[0])
gf
# Out:
#    department         education gender  no_of_trainings  age  \
# 0  Technology  Master's & above      m                1   34
#
#    previous_year_rating  length_of_service  awards_won  avg_training_score
# 0                   5.0                  7           0                78.0

# %%
prediction=model.predict(gf)
print(prediction)
if (prediction[0]==0):
    print("is not pramoted")
else:
    print("is pramoted")
# Out:
# [1]
# is pramoted

# %%
import pickle
import pandas as pd

# %%
with open("final_model.sav",mode = 'wb') as f1:
    pickle.dump(model,f1)
